# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the dataset

# %%
data = pd.read_csv('AssamEmployment.csv')
data
# Out:
#         fin_year  month  state_code state_name  district_code  district_name  \
# 0      2018-2019    May           4      ASSAM            402      KOKRAJHAR
# 1      2018-2019    May           4      ASSAM            403     BONGAIGAON
# 2      2018-2019    May           4      ASSAM            404       GOALPARA
# 3      2018-2019    May           4      ASSAM            412       Morigaon
# 4      2018-2019    May           4      ASSAM            419  KARBI ANGLONG
# ...          ...    ...         ...        ...            ...            ...
# 12015  2025-2026  April           4      ASSAM            415         JORHAT
# 12016  2025-2026  April           4      ASSAM            418       TINSUKIA
# 12017  2025-2026  April           4      ASSAM            424          BAKSA
# 12018  2025-2026  April           4      ASSAM            429          HOJAI
# 12019  2025-2026  April           4      ASSAM            432         MAJULI
#
# ...

# %% [markdown]
# # Data Analysis

# %%
data.shape
# Out:
# (12020, 36)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12020 entries, 0 to 12019
# Data columns (total 36 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   fin_year                                               12020 non-null  object
#  1   month                                                  12020 non-null  object
#  2   state_code                                             12020 non-null  int64
#  3   state_name                                             12020 non-null  object
#  4   district_code                                          12020 non-null  int64
#  5   district_name                                          12020 non-null  object
#  6   Approved_Labour_Budget                                 12020 non-null  int64
#  7   Average_Wage_rate_per_day_per_person                   12020 non-null  float64
# ...

# %%
data.describe(include='all')
# Out:
#          fin_year  month  state_code state_name  district_code district_name  \
# count       12020  12020     12020.0      12020   12020.000000         12020
# unique          8     12         NaN          1            NaN            36
# top     2024-2025   July         NaN      ASSAM            NaN         BAKSA
# freq         9492   1108         NaN      12020            NaN           350
# mean          NaN    NaN         4.0        NaN     417.807488           NaN
# std           NaN    NaN         0.0        NaN      10.014012           NaN
# min           NaN    NaN         4.0        NaN     401.000000           NaN
# 25%           NaN    NaN         4.0        NaN     409.000000           NaN
# 50%           NaN    NaN         4.0        NaN     418.000000           NaN
# 75%           NaN    NaN         4.0        NaN     426.000000           NaN
# max           NaN    NaN         4.0        NaN     435.000000           NaN
#
# ...

# %%
data.isnull().sum()
# Out:
# fin_year                                                     0
# month                                                        0
# state_code                                                   0
# state_name                                                   0
# district_code                                                0
# district_name                                                0
# Approved_Labour_Budget                                       0
# Average_Wage_rate_per_day_per_person                         0
# Average_days_of_employment_provided_per_Household            0
# Differently_abled_persons_worked                             0
# Material_and_skilled_Wages                                   0
# Number_of_Completed_Works                                    0
# Number_of_GPs_with_NIL_exp                                   0
# Number_of_Ongoing_Works                                      0
# Persondays_of_Central_Liability_so_far                       0
# ...

# %% [markdown]
# # Data Cleaning

# %%
mean = data['percentage_payments_gererated_within_15_days'].mean()
print(mean)
data['Remarks'] = ['Good' if x > mean else 'Bad' for x in data['percentage_payments_gererated_within_15_days']]
data["Remarks"]
# Out:
# 99.84954908485858
# 0        Good
# 1        Good
# 2        Good
# 3        Good
# 4        Good
#          ...
# 12015    Good
# 12016     Bad
# 12017     Bad
# 12018    Good
# 12019     Bad
# Name: Remarks, Length: 12020, dtype: object

# %%
data.columns
# Out:
# Index(['fin_year', 'month', 'state_code', 'state_name', 'district_code',
#        'district_name', 'Approved_Labour_Budget',
#        'Average_Wage_rate_per_day_per_person',
#        'Average_days_of_employment_provided_per_Household',
#        'Differently_abled_persons_worked', 'Material_and_skilled_Wages',
#        'Number_of_Completed_Works', 'Number_of_GPs_with_NIL_exp',
#        'Number_of_Ongoing_Works', 'Persondays_of_Central_Liability_so_far',
#        'SC_persondays', 'SC_workers_against_active_workers', 'ST_persondays',
#        'ST_workers_against_active_workers', 'Total_Adm_Expenditure',
#        'Total_Exp', 'Total_Households_Worked', 'Total_Individuals_Worked',
#        'Total_No_of_Active_Job_Cards', 'Total_No_of_Active_Workers',
#        'Total_No_of_HHs_completed_100_Days_of_Wage_Employment',
#        'Total_No_of_JobCards_issued', 'Total_No_of_Workers',
#        'Total_No_of_Works_Takenup', 'Wages', 'Women_Persondays',
#        'percent_of_Category_B_Works',
# ...

# %%
data1 = data.drop(['state_code','district_code','Material_and_skilled_Wages','Number_of_GPs_with_NIL_exp','Persondays_of_Central_Liability_so_far','Total_Adm_Expenditure',],axis=1)

# %% [markdown]
# Finding Outliers

# %%
# numeric_cols = data1.select_dtypes(include='number').columns
numeric_cols = data1.select_dtypes(include=[np.number])
outliers_dict = {}
for col in numeric_cols:
    Q1 = np.percentile(data1[col], 25)
    Q3 = np.percentile(data1[col], 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data1[(data1[col] < lower_bound) | (data1[col] > upper_bound)]
    outliers_dict[col] = len(outliers)

outliers_summary = pd.DataFrame.from_dict(outliers_dict, orient='index', columns=['Number of Outliers'])
outliers_summary.sort_values(by='Number of Outliers', ascending=False)
# Out:
#                                                     Number of Outliers
# Average_Wage_rate_per_day_per_person                              3061
# percentage_payments_gererated_within_15_days                      2046
# Total_No_of_HHs_completed_100_Days_of_Wage_Empl...                1621
# ST_persondays                                                     1422
# percent_of_NRM_Expenditure                                        1411
# Differently_abled_persons_worked                                  1214
# ST_workers_against_active_workers                                 1042
# SC_persondays                                                      602
# percent_of_Category_B_Works                                        534
# Number_of_Completed_Works                                          456
# Total_No_of_JobCards_issued                                        395
# Women_Persondays                                                   305
# ...

# %%
plt.figure(figsize=(18, 8))
data1.boxplot()
plt.title('Boxplot for All Numeric Columns')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
for col in numeric_cols:
    data1[col] = data1[col].astype(float)

    Q1 = np.percentile(data1[col], 25)
    Q3 = np.percentile(data1[col], 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    data1[col] = np.where(data1[col] < lower_bound, lower_bound, data1[col])
    data1[col] = np.where(data1[col] > upper_bound, upper_bound, data1[col])

# %%
plt.figure(figsize=(18, 8))
data1.boxplot()
plt.title('Boxplot for All Numeric Columns')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Distribution of Employment Among Differently Abled Persons by District

# %%
district_data = data1.groupby('district_name')['Differently_abled_persons_worked'].sum()
plt.figure(figsize=(12, 12))
plt.pie(district_data,labels=district_data.index)
plt.title('Differently Abled Persons Worked by District')
plt.show()

# %% [markdown]
# ## Total Number of Completed Works Across Districts

# %%
completed_works = data1.groupby('district_name')['Number_of_Completed_Works'].sum().sort_values(ascending=False)
plt.figure(figsize=(10, 5))
completed_works.plot(kind='bar',color='blue')
plt.title('Number of Completed Works by District')
plt.xlabel('District Name')
plt.ylabel('Number of Completed Works')
plt.show()

# %% [markdown]
# ## Monthly Trend of Average Employment Days Provided per Household (by Financial Month)

# %%
month_order = ['April', 'May', 'June', 'July', 'August', 'September',
               'October', 'November', 'December', 'January', 'February', 'March']
data1['month'] = pd.Categorical(data1['month'], categories=month_order, ordered=True)

plt.figure(figsize=(10, 5))
for year in data1['fin_year'].unique():
    yearly_data = data1[data1['fin_year'] == year]
    avg_by_month = yearly_data.groupby('month',observed=False)['Average_days_of_employment_provided_per_Household'].mean().reindex(month_order)
    plt.plot(month_order, avg_by_month, marker='o', label=year)

plt.title('Avg Employment Days per Household (by Month)')
plt.xlabel('Month')
plt.ylabel('Avg Days')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Monthly Trend of Total Individuals Worked

# %%
plt.figure(figsize=(10, 5))
for year in data1['fin_year'].unique():
    yearly_data = data1[data1['fin_year'] == year]
    total_by_month = yearly_data.groupby('month',observed=False)['Total_Individuals_Worked'].sum().reindex(month_order)
    plt.plot(month_order, total_by_month, marker='s', label=year)

plt.title('Total Individuals Worked (by Month)')
plt.xlabel('Month')
plt.ylabel('Total Individuals')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Total Number of Households Worked by District

# %%
plt.figure(figsize=(14, 6))
district_work = data1.groupby('district_name',observed=False)['Total_Households_Worked'].sum().sort_values(ascending=False)
sns.barplot(x=district_work.values, y=district_work.index,hue=district_work.index, palette='viridis')
plt.title('Total Households Worked by District')
plt.xlabel('Total Households Worked')
plt.ylabel('District')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Top 10 Districts by Total Number of Job Cards Issued

# %%
top10_jobcards = data1.groupby('district_name')['Total_No_of_JobCards_issued'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(8, 8))
plt.pie(top10_jobcards, labels=top10_jobcards.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Set3'))
plt.title('Top 10 Districts by Job Cards Issued')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Relationship Between Wages and Average Days of Employment Provided per Household

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data1, x='Average_days_of_employment_provided_per_Household', y='Wages', hue='district_name', legend=False)
plt.title('Wages vs Average Days of Employment Provided per Household')
plt.xlabel('Average Days of Employment')
plt.ylabel('Total Wages Paid')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Distribution of Women, SC, and ST Persondays by District

# %%
district_group = data1.groupby('district_name')[['Women_Persondays', 'SC_persondays', 'ST_persondays']].sum().reset_index()

plt.figure(figsize=(16, 8))
bottom1 = district_group['Women_Persondays']
bottom2 = bottom1 + district_group['SC_persondays']

plt.bar(district_group['district_name'], district_group['Women_Persondays'], label='Women Persondays')
plt.bar(district_group['district_name'], district_group['SC_persondays'], bottom=bottom1, label='SC Persondays')
plt.bar(district_group['district_name'], district_group['ST_persondays'], bottom=bottom2, label='ST Persondays')

plt.xticks(rotation=90)
plt.ylabel('Persondays')
plt.title('Women, SC and ST Persondays by District (Stacked)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Comparison of Completed and Ongoing Works by District

# %%
works_by_district = data1.groupby('district_name')[['Number_of_Completed_Works', 'Number_of_Ongoing_Works']].sum().reset_index()

x = works_by_district['district_name']
width = 0.35
x_axis = range(len(x))

plt.figure(figsize=(16, 7))
plt.bar(x_axis, works_by_district['Number_of_Completed_Works'], width=width, label='Completed Works')
plt.bar([i + width for i in x_axis], works_by_district['Number_of_Ongoing_Works'], width=width, label='Ongoing Works')

plt.xticks([i + width / 2 for i in x_axis], x, rotation=90)
plt.ylabel("Number of Works")
plt.title("Completed vs Ongoing Works by District")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation Heatmap of Key Employment Metrics in Assam

# %%
columns_of_interest = [
    'Approved_Labour_Budget',
    'Average_Wage_rate_per_day_per_person',
    'Average_days_of_employment_provided_per_Household',
    'Differently_abled_persons_worked',
    'Total_No_of_JobCards_issued',
    'Total_No_of_Workers',
    'Total_No_of_Works_Takenup',
    'Wages',
    'Women_Persondays',
    'percent_of_Category_B_Works',
    'percent_of_Expenditure_on_Agriculture_Allied_Works',
    'percent_of_NRM_Expenditure',
    'percentage_payments_gererated_within_15_days'
]

df_cleaned = data1[columns_of_interest].apply(pd.to_numeric, errors='coerce')

correlation_matrix = df_cleaned.corr()

plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="YlGnBu", fmt=".2f", linewidths=0.5)
plt.title("Heatmap of Employment Metrics Correlation - Assam")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Trend of Average Wage Rate per Day per Person Across Financial Years

# %%
wage_trend = data1.groupby('fin_year')['Average_Wage_rate_per_day_per_person'].mean().reset_index()

plt.figure(figsize=(10, 5))
sns.lineplot(data=wage_trend, x='fin_year', y='Average_Wage_rate_per_day_per_person', marker='o')
plt.title('Average Wage Rate per Day per Person Over Financial Years')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Top 10 Districts by Average Percentage of Active Job Cards

# %%
data1['percentage_active_job_cards'] = (data1['Total_No_of_Active_Job_Cards'] / data1['Total_No_of_JobCards_issued']) * 100
district_percentage = data1.groupby('district_name')['percentage_active_job_cards'].mean().sort_values(ascending=False).head(10)

district_percentage
# Out:
# district_name
# MAJULI        82.653248
# HAILAKANDI    70.865927
# Biswanath     65.840728
# DHEMAJI       65.594248
# Morigaon      64.215060
# SIVASAGAR     64.177595
# DIBRUGARH     64.176667
# NALBARI       63.187422
# GOLAGHAT      62.863965
# UDALGURI      62.754534
# Name: percentage_active_job_cards, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=district_percentage.values, y=district_percentage.index,hue=district_percentage.index, palette='viridis')
plt.xlabel('Percentage of Active Job Cards')
plt.ylabel('District Name')
plt.title('Top 10 Districts by Percentage of Active Job Cards')
# plt.xlim(0, 110)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## District-wise Comparison of Total and Active Workers (in Millions)

# %%
district_workers = data1.groupby('district_name')[['Total_No_of_Workers', 'Total_No_of_Active_Workers']].sum()
district_workers.columns = ['Total_Workers', 'Active_Workers']

plt.figure(figsize=(14, 7))
bar_width = 0.4
index = range(len(district_workers))

plt.bar(index, district_workers['Total_Workers'] / 1e6, bar_width, label='Total Workers', color='black')
plt.bar([i + bar_width for i in index], district_workers['Active_Workers'] / 1e6, bar_width, label='Active Workers', color='green')

plt.xlabel('District')
plt.ylabel('Number of Workers (in Millions)')
plt.title('District-wise Details of Total Workers and Active Workers')
plt.xticks([i + bar_width / 2 for i in index], district_workers.index, rotation=45, ha='right')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## District-wise Analysis: Average Days of Employment vs Total Households Worked

# %%
district_data = data1.groupby('district_name')[['Average_days_of_employment_provided_per_Household', 'Total_Households_Worked']].mean()
plt.figure(figsize=(12, 7))
sns.scatterplot(data=district_data,
                x='Average_days_of_employment_provided_per_Household',
                y='Total_Households_Worked',
                hue='district_name',
                palette='tab20',
                s=100,
                legend=True)

plt.title('District-wise: Average Days of Employment vs Total Households Worked')
plt.xlabel('Average Days of Employment Provided per Household')
plt.ylabel('Total Households Worked')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
for col in numeric_cols:
    plt.figure(figsize=(30, 6))
    sns.histplot(data1[col], kde=True, bins=50, color='blue')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.tight_layout()
    plt.show()
